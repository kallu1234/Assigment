# %%
L1=list('kalyani')
print(L1)
# Out:
# ['k', 'a', 'l', 'y', 'a', 'n', 'i']

# %%
L=[2,5,1,7]
L[3]=12
print(L)
# Out:
# [2, 5, 1, 12]

# %%
L.append(12)
print(L)
# Out:
# [2, 5, 1, 12, 12]

# %%
L.extend((21,'hi',[3,6,4]))
print(L)
# Out:
# [2, 5, 1, 12, 12, 21, 'hi', [3, 6, 4]]

# %%
Colors=['red','blue','green']
L2=Colors
print(L2)
# Out:
# ['red', 'blue', 'green']

# %%
id(Colors)
# Out:
# 1490344119936

# %%
id(L2)
# Out:
# 1490344119936

# %%
L2=list(Colors)
id(L2)
# Out:
# 1490343792384

# %%
L3=L+L2
print(L3)
# Out:
# [2, 5, 1, 12, 12, 21, 'hi', [3, 6, 4], 'red', 'blue', 'green']

# %%
l=[1,2,3,1,27,9]
l.index(2)
l.insert(2,4)
l.remove(3)
l
# Out:
# [1, 2, 4, 1, 27, 9]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
L2.reverse()
print(L2)
L2.sort()
print(L2)
L2.sort(reverse=True)
print(L2)
# Out:
# ['blue', 'green', 'red']
# ['blue', 'green', 'red']
# ['red', 'green', 'blue']

# %%
List=[1,2,3,4,5,6,7,8,9]
print(List[::3])
# Out:
# [1, 4, 7]

# %%
a=[]
for i in range(1,4):
    a.append(i)
    print(a)
# Out:
# [1]
# [1, 2]
# [1, 2, 3]

# %%
b=[1,2,3,4,5]
print(b[3:0:-1])
# Out:
# [4, 3, 2]

# %%
t=(1,"hello",'w',3.2)
t2=tuple('harsh')
print(t2)
# Out:
# ('h', 'a', 'r', 's', 'h')

# %%
t=(1,2,'A','B')
w,x,y,z=t
print(w,x,y,z,sep='*')
# Out:
# 1*2*A*B

# %%
t=(((('a',1),'b','c'),'d',2),'e',3)
len(t)
# Out:
# 3

# %%
A=("Hello","Harsh","How are","you?")
(a,b,c,d)=A
print(a,b,c,d)
# Out:
# Hello Harsh How are you?

# %%
A=(a,b,c,d)
print(A[0][0]+A[1][1],A[1])
# Out:
# Ha Harsh
